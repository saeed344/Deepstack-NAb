# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load features
path = "/content/drive/MyDrive/Watashara_Projects/8-Dengue/features/"

AAC_Antibody = pd.read_csv(path + 'AAC_Antibody.csv').iloc[:, 1:].values
AAI_Antibody = pd.read_csv(path + 'AAINDEX_Antibody.csv').iloc[:, 1:].values
APAAC_Antibody = pd.read_csv(path + 'APAAC_Antibody.csv').iloc[:, 1:].values
CTDC_Antibody = pd.read_csv(path + 'CTDC_Antibody.csv').iloc[:, 1:].values
CTDD_Antibody = pd.read_csv(path + 'CTDD_Antibody.csv').iloc[:,1:].values
DPC_Antibody = pd.read_csv(path + 'DPC_Antibody.csv').iloc[:, 1:].values
EAAC_Antibody = pd.read_csv(path + 'EAAC_Antibody.csv').iloc[:, 1:].values
FEGS_Antibody = pd.read_csv(path + 'FEGS_Antibody.csv').iloc[:, :].values
DCGR_Antibody = pd.read_csv(path + 'DCGR_Antibody_features.csv').iloc[:, :].values
BLOSUM62_Antibody = pd.read_csv(path + 'BLOSUM62_Antibody.csv').iloc[:, 1:].values
word2vec_Antibody = pd.read_csv(path + 'Antibody_word2vec.csv').iloc[:, 1:].values
bert_Antibody = pd.read_csv(path + 'Antibody_bert.csv').iloc[:, 1:].values
# Fasttex_Antibody = pd.read_csv(path + 'Fasttext_Antibody.csv').iloc[:, 1:].values

AAC_Epitope = pd.read_csv(path + 'AAC_Epitope.csv').iloc[:, 1:].values
AAI_Epitope = pd.read_csv(path + 'AAINDEX_Epitope.csv').iloc[:, 1:].values
APAAC_Epitope = pd.read_csv(path + 'APAAC_Epitope.csv').iloc[:, 1:].values
CTDC_Epitope = pd.read_csv(path + 'CTDC_Epitope.csv').iloc[:, 1:].values
CTDD_Epitope = pd.read_csv(path + 'CTDD_Epitope.csv').iloc[:,1:].values
DPC_Epitope = pd.read_csv(path + 'DPC_Epitope.csv').iloc[:, 1:].values
EAAC_Epitope = pd.read_csv(path + 'EAAC_Epitope.csv').iloc[:, 1:].values
FEGS_Epitope = pd.read_csv(path + 'FEGS_Epitope.csv').iloc[:, :].values
DCGR_Epitope = pd.read_csv(path + 'DCGR_Epitope_features.csv').iloc[:, :].values
BLOSUM62_Epitope = pd.read_csv(path + 'BLOSUM62_Epitope.csv').iloc[:, 1:].values
word2vec_Epitope = pd.read_csv(path + 'Epitope_word2vec.csv').iloc[:, 1:].values
bert_Epitope = pd.read_csv(path + 'Epitope_bert.csv').iloc[:, 1:].values
# Fasttext_Epitope = pd.read_csv(path + 'Fasttext_Epitope.csv').iloc[:, 1:].values


# Combine all features
# all_train_features = np.column_stack((AAC,AAI,ASDC, CTDC,CTDD, CTDT, DDE, onehot,OPF, Train_FEGS,word2vec,bert))#, KR, KRC, PubChem, RDKIT



# print(np.shape(Fasttext_Epitope))
# Combine all features
AAC = np.column_stack((AAC_Antibody,AAC_Epitope))
# AAI = np.column_stack((AAI_Antibody, AAI_Epitope))
APAAC = np.column_stack((APAAC_Antibody,APAAC_Epitope))
CTDC = np.column_stack((CTDC_Antibody,CTDC_Epitope))
# CTDD = np.column_stack((CTDD_Antibody,CTDD_Epitope))
# DPC = np.column_stack((DPC_Antibody,DPC_Epitope))
# EAAC = np.column_stack((EAAC_Antibody,EAAC_Epitope))
FEGS = np.column_stack((FEGS_Antibody,FEGS_Epitope))
DCGR = np.column_stack((DCGR_Antibody,DCGR_Epitope))
BLOSUM62 = np.column_stack((BLOSUM62_Antibody,BLOSUM62_Epitope))
word2vec = np.column_stack((word2vec_Antibody,word2vec_Epitope))
bert = np.column_stack((bert_Antibody,bert_Epitope))
# Fasttext = np.column_stack((Fasttex_Antibody,Fasttext_Epitope))


all_features = np.column_stack((AAC_Antibody,AAC_Epitope,APAAC_Antibody, APAAC_Epitope, CTDC_Antibody, CTDC_Epitope,
                                    FEGS_Antibody,FEGS_Epitope,DCGR_Antibody,DCGR_Epitope,BLOSUM62_Antibody,
                                BLOSUM62_Epitope,word2vec_Antibody,word2vec_Epitope,bert_Antibody,bert_Epitope))
print(np.shape(AAC))
print(np.shape(APAAC))
print(np.shape(CTDC))
print(np.shape(FEGS))
print(np.shape(DCGR))
print(np.shape(BLOSUM62))
print(np.shape(word2vec_Antibody))
print(np.shape(bert))
# print(np.shape(all_features))

# labela=np.ones((554 ,1))  #Value can be changed
# labelb=np.zeros((554,1))
# labels=np.append(labela,labelb)
# y = labels
# X_train,X_test,y_train,y_test = train_test_split(all_features, labels, test_size=0.2, random_state=42)

# print(np.shape(X_train))
# print(np.shape(y_train))
# print(np.shape(X_test))
# print(np.shape(y_test))
# Out:
# (1108, 40)
# (1108, 44)
# (1108, 78)
# (1108, 1156)
# (1108, 100)
# (1108, 40)
# (1108, 219)
# (1108, 1534)

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import pandas as pd
import math

def categorical_probas_to_classes(p):
    return np.argmax(p, axis=1)

def to_categorical(y, nb_classes=None):
    '''Convert class vector (integers from 0 to nb_classes)
    to binary class matrix, for use with categorical_crossentropy.
    '''
    y = np.array(y, dtype='int')
    if not nb_classes:
        nb_classes = np.max(y)+1
    Y = np.zeros((len(y), nb_classes))
    for i in range(len(y)):
        Y[i, y[i]] = 1.
    return Y


def calculate_performace(test_num, pred_y, labels):
    tp = 0
    fp = 0
    tn = 0
    fn = 0
    for index in range(test_num):
        if labels[index] == 1:
            if labels[index] == pred_y[index]:
                tp = tp + 1
            else:
                fn = fn + 1
        else:
            if labels[index] == pred_y[index]:
                tn = tn + 1
            else:
                fp = fp + 1

    acc = float(tp + tn) / test_num
    precision = float(tp) / (tp + fp + 1e-06)
    npv = float(tn) / (tn + fn + 1e-06)
    sensitivity = float(tp) / (tp + fn + 1e-06)
    specificity = float(tn) / (tn + fp + 1e-06)
    mcc = float(tp * tn - fp * fn) / (math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) + 1e-06)
    f1 = float(tp * 2) / (tp * 2 + fp + fn + 1e-06)
    return acc, precision, npv, sensitivity, specificity, mcc, f1

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten, GRU, Bidirectional, Conv1D, MaxPooling1D
from tensorflow.keras.models import Sequential, model_from_json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import StratifiedKFold, train_test_split
from tensorflow.keras.utils import to_categorical
from imblearn.over_sampling import SMOTE, BorderlineSMOTE
from imblearn.under_sampling import RandomUnderSampler
import os
from sklearn.preprocessing import StandardScaler

# Initialize the model
# model = Sequential()
# model.add(GRU(32, return_sequences=True))
# model.add(Dropout(0.5))
# model.add(GRU(16, return_sequences=True))
# model.add(Dropout(0.5))
# model.add(Flatten())
# model.add(Dense(64, activation='sigmoid', name="Dense_64"))
# model.add(Dropout(0.7))
# model.add(Dense(16, activation='sigmoid', name="Dense_16"))
# model.add(Dense(2, activation='sigmoid', name="Dense_2"))
# model.compile(loss='categorical_crossentropy', optimizer='adamax', metrics=['accuracy'])
model = Sequential()
model.add(GRU(256,return_sequences=True))
model.add(Dropout(0.05))
model.add(GRU(256,return_sequences=True))
model.add(Dropout(0.05))
model.add(Flatten())
model.add(Dense(128, activation = 'relu',name="Dense_64"))
model.add(Dropout(0.05))
model.add(Dense(64, activation = 'relu',name="Dense_16"))
model.add(Dropout(0.05))
model.add(Dense(2, activation = 'softmax',name="Dense_2"))
model.compile(loss = 'binary_crossentropy', optimizer = 'Adagrad', metrics =['accuracy'])#rmsprop


path = "/content/drive/MyDrive/Watashara_Projects/8-Dengue/"
data_ = pd.read_csv(path + 'Feature_Selection/GLasso_feat.csv')
# csv_file = pd.read_csv(path+ 'Feature_Selection/GLasso_Train_feat.csv')
# deep_llm_feat_train = np.column_stack((port_feat_train, Train_BiGRU_1500))
data_np = np.array(data_)
data_scaled = scale(data_np[:, :])
print(np.shape(data_np))

label1=np.ones((554 ,1))#Value can be changed
label2=np.zeros((554 ,1))
label=np.append(label1,label2)


X_train, X_ind, y_train, y_ind = train_test_split(data_scaled, label, test_size=0.2, random_state=42)
# X = np.array(X_train,dtype=float)
# y = y_train
X = X_train
y = y_train

# from imblearn.over_sampling import SMOTE, BorderlineSMOTE
# oversample = SMOTE()
# X_train, y_train = oversample.fit_resample(X_train, y_train)
# oversample = SMOTE()
# X_train, y_train = oversample.fit_resample(X_train, y_train)


fld_name = 'all_feat_GRU'

if not os.path.exists(path + (f'Results/{fld_name}/')):
    os.makedirs(path + f'Results/{fld_name}/')


[m1, n1] = np.shape(X)

X = np.reshape(X, (-1, 1, n1))


# Cross-validation
sepscores = []
ytest = np.ones((1, 2)) * 0.5
yscore = np.ones((1, 2)) * 0.5
skf = StratifiedKFold(n_splits=5)

for i, (train, test) in enumerate (skf.split(X,y)):
    y_train = to_categorical(y[train])
    y_test = to_categorical(y[test])
    history = model.fit(X[train], y_train, validation_data=(X[test], y_test), batch_size=28, epochs=80)
    model.summary()
    y_score = model.predict(X[test])
    y_class= categorical_probas_to_classes(y_score)

    ytest = np.vstack((ytest, y_test))
    y_test_tmp = y[test]
    yscore = np.vstack((yscore, y_score))

    # Calculate performance
    acc, precision, npv, sensitivity, specificity, mcc, f1 = calculate_performace(len(y_class), y_class, y[test])
    fpr, tpr, _ = roc_curve(y_test[:, 1], y_score[:, 1])
    roc_auc = auc(fpr, tpr)
    sepscores.append([acc,  sensitivity, specificity, mcc, f1, roc_auc])
    print('GRU:acc=%f,sensitivity=%f,specificity=%f,mcc=%f,f1=%f,roc_auc=%f'
          % (acc,  sensitivity, specificity, mcc,f1, roc_auc))
    model.save( path + f'Results/{fld_name}/' + str(i) + 'GRU_new.keras')


# Save results
scores = np.array(sepscores)
result1 = np.mean(scores, axis=0)
H1 = result1.tolist()
sepscores.append(H1)
result = sepscores

row = yscore.shape[0]
yscore = yscore[np.array(range(1, row)), :]
yscore_sum = pd.DataFrame(data=yscore)
yscore_sum.to_csv(path + f'Results/{fld_name}/GRU_yscore.csv')

ytest = ytest[np.array(range(1, row)), :]
ytest_sum = pd.DataFrame(data=ytest)
ytest_sum.to_csv(path + f'Results/{fld_name}/GRU_ytest.csv')

data_csv = pd.DataFrame(data=result)
data_csv.to_csv(path + f'Results/{fld_name}/GRU_CV_results.csv')

# Plot history
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('Accuracy_loss')
plt.xlabel('Epoch')
plt.show()
# Out:
# (1108, 279)
# Epoch 1/80
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.4887 - loss: 0.6949 - val_accuracy: 0.4888 - val_loss: 0.6955
# Epoch 2/80
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5198 - loss: 0.6939 - val_accuracy: 0.4888 - val_loss: 0.6952
# Epoch 3/80
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5076 - loss: 0.6937 - val_accuracy: 0.4944 - val_loss: 0.6949
# Epoch 4/80
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5072 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6946
# Epoch 5/80
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5225 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6943
# Epoch 6/80
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5130 - loss: 0.6944 - val_accuracy: 0.5000 - val_loss: 0.6941
# Epoch 7/80
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5092 - loss: 0.6930 - val_accuracy: 0.5056 - val_loss: 0.6938
# Epoch 8/80
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale
from sklearn.metrics import roc_curve, auc
from tensorflow.keras.models import Sequential, load_model
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import pandas as pd
import math

# csv_file = pd.read_csv(path+ 'Feature_Selection/deep_llm_feat_ind.csv')
# deep_llm_feat_train = np.column_stack((port_feat_train, Train_BiGRU_1500))
# data_np = np.array(deep_llm_feat_ind)
# Xt = data_np[:, :]
# labela=np.ones((235,1))  #Value can be changed
# labelb=np.zeros((235,1))
# labels=np.append(labela,labelb)
# yt = labels
Xt = X_ind
yt = y_ind

#
print(Xt.shape)
print(yt.shape)
###########################################################################################
[sample_num, input_dim] = np.shape(Xt)
Xt = np.reshape(Xt, (-1, 1, input_dim))



sepscores = []
ytest = np.ones((1, 2)) * 0.5
yscore = np.ones((1, 2)) * 0.5

for i in range(5):

    loaded_model = load_model( path + f'Results/{fld_name}/' + str(i) + 'GRU_new.keras')
    print("Loaded model from disk")

    # evaluate loaded model on test data

    y_score = loaded_model.predict(Xt)
    y_class = categorical_probas_to_classes(y_score)

    y_test = to_categorical(yt)
    ytest = np.vstack((ytest, y_test))
    y_test_tmp = yt
    yscore = np.vstack((yscore, y_score))

    acc, precision, npv, sensitivity, specificity, mcc, f1 = calculate_performace(len(y_class), y_class, y_test_tmp)
    fpr, tpr, _ = roc_curve(y_test[:, 1], y_score[:, 1])
    roc_auc = auc(fpr, tpr)
    sepscores.append([acc, sensitivity, specificity, mcc, f1, roc_auc])
    print(f'CNN:acc={acc:.6f},sensitivity={sensitivity:.6f},specificity={specificity:.6f},mcc={mcc:.6f},f1={f1:.6f},roc_auc={roc_auc:.6f}')


row=ytest.shape[0]
ytest=ytest[np.array(range(1,row)),:]
ytest_sum = pd.DataFrame(data=ytest)
ytest_sum.to_csv(path + f'Results/{fld_name}/GRU_ytest_test.csv')

yscore_=yscore[np.array(range(1,row)),:]
yscore_sum = pd.DataFrame(data=yscore_)
yscore_sum.to_csv(path + f'Results/{fld_name}/GRU_yscore_test.csv')

scores = np.array(sepscores)
result1 = np.mean(scores, axis=0)
H1 = result1.tolist()
sepscores.append(H1)
result = sepscores

data_csv = pd.DataFrame(data=result)
data_csv.to_csv(path + f'Results/{fld_name}/GRU_test_results.csv')
# Out:
# (222, 279)
# (222,)
# Loaded model from disk
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# CNN:acc=0.756757,sensitivity=0.655172,specificity=0.867925,mcc=0.532177,f1=0.737864,roc_auc=0.852554
# Loaded model from disk
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# CNN:acc=0.806306,sensitivity=0.810345,specificity=0.801887,mcc=0.612008,f1=0.813853,roc_auc=0.913793
# Loaded model from disk
# ...

# %%
from tensorflow.keras.layers import Dense, Dropout, GRU, Bidirectional, Conv1D, MaxPooling1D, Flatten, BatchNormalization, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Load Data
path = "/content/drive/MyDrive/Watashara_Projects/HPep/"
# csv_file = pd.read_csv(path + 'Feature_Selection/GLasso_prot_GRU_train.csv')
data_np = np.array(deep_llm_feat_train)
X = data_np[:, :]
print("Input shape:", np.shape(X))

# Labels
label1 = np.ones((939, 1))  # Update these counts if necessary
label2 = np.zeros((939, 1))
labels = np.append(label1, label2)
y = labels.ravel()

# Standardize and Reshape
scaler = StandardScaler()
X = scaler.fit_transform(X)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))  # Shape: (samples, features, channels)

# Handle Class Imbalance
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X.reshape(X.shape[0], -1), y)
X_resampled = X_resampled.reshape(X_resampled.shape[0], X.shape[1], 1)  # Reshape back

# Initialize the model
model = Sequential([
    Input(shape=(X_resampled.shape[1], 1)),
    Conv1D(64, kernel_size=3, activation='relu', padding='same'),
    MaxPooling1D(pool_size=2),
    BatchNormalization(),
    Bidirectional(GRU(32, return_sequences=True, kernel_regularizer='l2')),
    Dropout(0.4),
    GRU(16, return_sequences=False, kernel_regularizer='l2'),
    Dropout(0.4),
    Dense(64, activation='relu', kernel_regularizer='l2'),
    Dropout(0.5),
    Dense(16, activation='relu', kernel_regularizer='l2'),
    Dense(1, activation='sigmoid')  # Binary classification
])
model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=['accuracy']
)

# Cross-validation
skf = StratifiedKFold(n_splits=5)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
history_dict = {}

for i, (train_idx, test_idx) in enumerate(skf.split(X_resampled, y_resampled)):
    print(f"Fold {i+1}")
    X_train, X_test = X_resampled[train_idx], X_resampled[test_idx]
    y_train, y_test = y_resampled[train_idx], y_resampled[test_idx]

    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        batch_size=32,
        epochs=100,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    # Save model for each fold
    fld_name = 'GLasso_prot_GRU'
    if not os.path.exists(path + f'Results/{fld_name}/'):
        os.makedirs(path + f'Results/{fld_name}/')
    model.save(path + f'Results/{fld_name}/GRU_fold_{i}.keras')

    history_dict[i] = history.history

# Save Results
pd.DataFrame(history_dict).to_csv(path + f'Results/{fld_name}/training_history.csv')

# Plot Training History
plt.figure(figsize=(12, 6))
for i in range(len(history_dict)):
    plt.plot(history_dict[i]['accuracy'], label=f'Fold {i+1} Train')
    plt.plot(history_dict[i]['val_accuracy'], label=f'Fold {i+1} Val')

plt.legend()
plt.title('Cross-Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Input shape: (1878, 3548)
# Fold 1
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 223s 5s/step - accuracy: 0.5451 - loss: 2.9997 - val_accuracy: 0.5000 - val_loss: 2.2032 - learning_rate: 0.0010
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 237s 4s/step - accuracy: 0.5590 - loss: 2.0066 - val_accuracy: 0.5266 - val_loss: 1.5308 - learning_rate: 0.0010
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 212s 4s/step - accuracy: 0.5671 - loss: 1.4160 - val_accuracy: 0.5399 - val_loss: 1.1494 - learning_rate: 0.0010
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 194s 4s/step - accuracy: 0.5606 - loss: 1.0801 - val_accuracy: 0.5399 - val_loss: 0.9391 - learning_rate: 0.0010
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 200s 4s/step - accuracy: 0.5812 - loss: 0.9004 - val_accuracy: 0.5559 - val_loss: 0.8239 - learning_rate: 0.0010
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 199s 4s/step - accuracy: 0.5794 - loss: 0.8020 - val_accuracy: 0.5638 - val_loss: 0.7612 - learning_rate: 0.0010
# Epoch 7/100
# ...

# %% [markdown]
# **Indpendent data test **

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc, accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
import os

# Load Independent Test Data
path = "/content/drive/MyDrive/Watashara_Projects/HPep/"
fld_name = 'GLasso_prot_GRU'  # Ensure this matches the training folder name
csv_file = pd.read_csv(path + 'Feature_Selection/deep_llm_feat_ind.csv')
data_np = np.array(csv_file)
Xt = data_np[:, :]  # Extract features
label_a = np.ones((235, 1))  # Update these counts if necessary
label_b = np.zeros((235, 1))
labels = np.append(label_a, label_b)
yt = labels.ravel()

# Preprocessing: Standardize and Reshape
scaler = StandardScaler()
Xt = scaler.fit_transform(Xt)
Xt = np.reshape(Xt, (Xt.shape[0], Xt.shape[1], 1))  # Shape: (samples, features, channels)

# Initialize arrays to store results
sepscores = []
ytest = np.ones((1, 2)) * 0.5  # Placeholder for test labels (categorical)
yscore = np.ones((1, 2)) * 0.5  # Placeholder for model predictions

# Iterate through each fold model
for i in range(5):
    # Load trained model for fold `i`
    model_path = path + f'Results/{fld_name}/GRU_fold_{i}.keras'
    loaded_model = load_model(model_path)
    print(f"Loaded model from disk: Fold {i}")

    # Predict on independent test data
    y_score = loaded_model.predict(Xt)
    y_class = (y_score > 0.5).astype(int).ravel()  # Convert probabilities to binary classes

    # One-hot encode test labels
    y_test = to_categorical(yt)
    ytest = np.vstack((ytest, y_test))
    yscore = np.vstack((yscore, y_score))

    # Calculate metrics
    acc = accuracy_score(yt, y_class)
    precision = precision_score(yt, y_class)
    npv = precision_score(yt, y_class, pos_label=0)  # Negative predictive value
    sensitivity = recall_score(yt, y_class)
    specificity = recall_score(yt, y_class, pos_label=0)
    mcc = matthews_corrcoef(yt, y_class)
    f1 = f1_score(yt, y_class)
    fpr, tpr, _ = roc_curve(yt, y_score.ravel())
    roc_auc = auc(fpr, tpr)

    # Store scores
    sepscores.append([acc, sensitivity, specificity, mcc, f1, roc_auc])
    print(f"Fold {i}: acc={acc:.6f}, sensitivity={sensitivity:.6f}, specificity={specificity:.6f}, "
          f"mcc={mcc:.6f}, f1={f1:.6f}, roc_auc={roc_auc:.6f}")

# Save Predictions and Metrics
row = ytest.shape[0]
ytest = ytest[1:, :]  # Remove placeholder
yscore = yscore[1:, :]  # Remove placeholder

pd.DataFrame(ytest).to_csv(path + f'Results/{fld_name}/GRU_ytest_test.csv', index=False)
pd.DataFrame(yscore).to_csv(path + f'Results/{fld_name}/GRU_yscore_test.csv', index=False)

# Calculate average metrics across folds
scores = np.array(sepscores)
mean_scores = np.mean(scores, axis=0)
sepscores.append(mean_scores.tolist())  # Append overall average scores

# Save all results
result_df = pd.DataFrame(sepscores, columns=['Accuracy', 'Sensitivity', 'Specificity', 'MCC', 'F1', 'ROC_AUC'])
result_df.to_csv(path + f'Results/{fld_name}/GRU_test_results.csv', index=False)
print("Results saved.")
# Out:
# (470, 3548)
# (470,)
# Loaded model from disk
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# CNN:acc=0.859574,sensitivity=0.910638,specificity=0.808511,mcc=0.722929,f1=0.866397,roc_auc=0.934613
# Loaded model from disk
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# CNN:acc=0.882979,sensitivity=0.923404,specificity=0.842553,mcc=0.768473,f1=0.887526,roc_auc=0.946329
# Loaded model from disk
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# CNN:acc=0.876596,sensitivity=0.940426,specificity=0.812766,mcc=0.759405,f1=0.884000,roc_auc=0.948212
# Loaded model from disk
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step
# CNN:acc=0.880851,sensitivity=0.923404,specificity=0.838298,mcc=0.764476,f1=0.885714,roc_auc=0.948592
# Loaded model from disk
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# CNN:acc=0.874468,sensitivity=0.944681,specificity=0.804255,mcc=0.756431,f1=0.882704,roc_auc=0.949534

# %%
# !pip install shap
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 8.3 MB/s eta 0:00:00
# ...

# %%
import shap
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Dense, Dropout, Flatten, GRU
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler

# Initialize the GRU model
model = Sequential()
model.add(GRU(32, return_sequences=True))
model.add(Dropout(0.5))
model.add(GRU(16, return_sequences=False))  # No return_sequences at the last GRU layer
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(64, activation='sigmoid', name="Dense_64"))
model.add(Dropout(0.7))
model.add(Dense(16, activation='sigmoid', name="Dense_16"))
model.add(Dense(2, activation='sigmoid', name="Dense_2"))
model.compile(loss='categorical_crossentropy', optimizer='adamax', metrics=['accuracy'])

# Custom prediction function to reshape input for the model
def model_predict_3D(X):
    # Reshape 2D data back to 3D (samples, 1, features) before passing to the model
    X_reshaped = X.reshape((X.shape[0], 1, X.shape[1]))  # Adding the time step dimension (1 in this case)
    return model.predict(X_reshaped)

# Load data
path = "/content/drive/MyDrive/Watashara_Projects/ACE/"
X_train = pd.read_csv(path + 'XtrainData_EN_wSMOTE.csv', header=0)

# Get feature names from the dataframe
feature_names = X_train.columns[:-1]  # Assuming the last column is the label

# Separate features and labels
Xt = X_train.iloc[:, :-1].values  # Test features (excluding last column for labels)
yt = X_train.iloc[:, -1].values   # Test labels (assuming the last column contains labels)

# # Normalize data if necessary
# scaler = StandardScaler()
# Xt_scaled = scaler.fit_transform(Xt)

# # Split into train and test sets (optional step based on your use case)
# X_train, X_test, y_train, y_test = train_test_split(Xt_scaled, yt, test_size=0.2, random_state=42)

# Use the 2D version of X_train for SHAP (no reshaping necessary)
X_test_2D = X_train

# Initialize the SHAP Kernel Explainer with the reshaped prediction function
explainer = shap.KernelExplainer(model_predict_3D, X_test_2D)

# Calculate SHAP values
shap_values = explainer.shap_values(X_test_2D)

# SHAP summary plot (bar chart for feature importance)
shap.summary_plot(shap_values, X_test_2D, feature_names=feature_names, plot_type="bar")

# SHAP dependency plot for a specific feature (e.g., feature 0)
shap.dependence_plot(0, shap_values[0], X_test_2D, feature_names=feature_names)

# SHAP force plot for the first instance in the test set
shap.force_plot(explainer.expected_value[0], shap_values[0][0, :], X_test_2D[0, :], feature_names=feature_names, matplotlib=True)

# SHAP summary for top 100 features
top_100_indices = np.argsort(np.abs(shap_values[0]).mean(0))[-100:]
plt.figure(figsize=(20, 15), dpi=300)
shap.summary_plot(shap_values[:, top_100_indices], X_test_2D[:, top_100_indices], feature_names=feature_names[top_100_indices], show=False)
plt.savefig(os.path.join(os.getcwd(), 'HD3Ci_shap_top100_training.pdf'), orientation='landscape', bbox_inches="tight", format='pdf', dpi=450)
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step
# WARNING:shap:Using 996 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/996 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
import shap
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Dense, Dropout, Flatten, GRU
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
import os

# Initialize the GRU model
model = Sequential()
model.add(GRU(32, return_sequences=True))
model.add(Dropout(0.5))
model.add(GRU(16, return_sequences=False))  # No return_sequences at the last GRU layer
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(64, activation='sigmoid', name="Dense_64"))
model.add(Dropout(0.7))
model.add(Dense(16, activation='sigmoid', name="Dense_16"))
model.add(Dense(2, activation='sigmoid', name="Dense_2"))
model.compile(loss='categorical_crossentropy', optimizer='adamax', metrics=['accuracy'])

# Custom prediction function to reshape input for the model
def model_predict_3D(X):
    X_reshaped = X.reshape((X.shape[0], 1, X.shape[1]))  # Adding the time step dimension (1 in this case)
    return model.predict(X_reshaped)

# Load data
path = "/content/drive/MyDrive/"
X_train = pd.read_csv(path + 'XtrainData_EN_wSMOTE.csv', header=0)

# Get feature names from the dataframe
feature_names = X_train.columns[:-1]  # Assuming the last column is the label

# Separate features and labels
Xt = X_train.iloc[:, :-1].values  # Test features (excluding last column for labels)
yt = X_train.iloc[:, -1].values   # Test labels (assuming the last column contains labels)

# Normalize data if necessary
scaler = StandardScaler()
Xt_scaled = scaler.fit_transform(Xt)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(Xt_scaled, yt, test_size=0.2, random_state=42)

# Use the 2D version of X_test for SHAP (no reshaping necessary)
X_test_2D = X_test

# Initialize the SHAP Kernel Explainer with the reshaped prediction function
explainer = shap.KernelExplainer(model_predict_3D, X_test_2D)

# Calculate SHAP values
shap_values = explainer.shap_values(X_test_2D)

plt.figure(figsize=(20, 15), dpi=300)
# SHAP summary plot (bar chart for feature importance)
shap.summary_plot(shap_values, X_test_2D, feature_names=feature_names, plot_type="bar")

# SHAP force plot for the first instance in the test set
shap.force_plot(explainer.expected_value[0], shap_values[0][0, :], X_test_2D[0, :], feature_names=feature_names, matplotlib=True)

# SHAP summary for top 50 features
top_50_indices = np.argsort(np.abs(shap_values[0]).mean(0))[-50:]

shap.summary_plot(np.array(shap_values[0])[:, top_50_indices], X_test_2D[:, top_50_indices], feature_names=feature_names[top_50_indices], show=False)
plt.savefig(os.path.join(os.getcwd(), 'HD3Ci_shap_top50_training.pdf'), orientation='landscape', bbox_inches="tight", format='pdf', dpi=450)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-eb8b731ff835> in <cell line: 32>()
#      30 # Load data
#      31 path = "/content/drive/MyDrive/"
# ---> 32 X_train = pd.read_csv(path + 'XtrainData_EN_wSMOTE.csv', header=0)
#      33
#      34 # Get feature names from the dataframe
#
# ...

# %%
import shap
import numpy as np

# Reduce the background data to K representative samples using K-means
K = 50  # Set the number of samples to a smaller value like 50

def model_predict_3D(X):
    # Reshape 2D data back to 3D (samples, 1, features) before passing to the model
    X_reshaped = X.reshape((X.shape[0], 1, X.shape[1]))  # Adding the time step dimension (1 in this case)
    return model.predict(X_reshaped)

# Use the 2D version of X_train for SHAP (no reshaping necessary)
X_test_2D = X_train
X_summary = shap.kmeans(X_test_2D, K)

# Initialize the SHAP Kernel Explainer with the reduced background data
explainer = shap.KernelExplainer(model_predict_3D, X_summary)

# Calculate SHAP values for the original test data
shap_values = explainer.shap_values(X_test_2D)

# SHAP summary plot
shap.summary_plot(shap_values, X_test_2D, plot_type="bar")

plt.figure(figsize=(20, 15), dpi=300)
shap.summary_plot(shap_values[:, top_20_indices], Xt_reshaped[:, top_20_indices], feature_names=sorted_feature_names, show=False, class_names=['Positive', 'Negative'])
ax = plt.gca()
fig = plt.gcf()
fig.savefig(os.path.join(os.getcwd(), 'HD3Ci_shap_top100_training.pdf'), orientation='landscape', bbox_inches="tight", format='pdf', dpi=450)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6e6aa1401e35> in <cell line: 13>()
#      11
#      12 # Use the 2D version of X_train for SHAP (no reshaping necessary)
# ---> 13 X_test_2D = X_train
#      14 X_summary = shap.kmeans(X_test_2D, K)
#      15
#
# NameError: name 'X_train' is not defined
